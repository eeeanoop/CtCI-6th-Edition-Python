# %% [markdown]
# <a href="https://colab.research.google.com/github/eeeanoop/CtCI-6th-Edition-Python/blob/master/python_cheatshee_practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('Hello I am Anoop')
# Out:
# Hello I am Anoop
